# %% [markdown]
# ![oops couldn't find image](Data-Science-Essentials-2020-header.png)

# %%
import pandas as pd

# %% [markdown]
# ***
# # Section 1 - Heart attack data

# %% [markdown]
# ### Create a DataFrame, ha_costs_df, from the mmd_heart_attack_data.csv file.

# %%
ha_costs_df = pd.read_csv('../data/mmd_heart_attack_data.csv')

# %% [markdown]
# Examine the first 5 rows of the TN heart attack data.

# %%
ha_costs_df.head(-1)
# Out:
#       year geography             measure         adjustment      analysis  \
# 0     2017    County  Average total cost  Unsmoothed actual  Base measure
# 1     2017    County  Average total cost  Unsmoothed actual  Base measure
# 2     2017    County  Average total cost  Unsmoothed actual  Base measure
# 3     2017    County  Average total cost  Unsmoothed actual  Base measure
# 4     2017    County  Average total cost  Unsmoothed actual  Base measure
# ...    ...       ...                 ...                ...           ...
# 2650  2017    County  Average total cost  Unsmoothed actual  Base measure
# 2651  2017    County  Average total cost  Unsmoothed actual  Base measure
# 2652  2017    County  Average total cost  Unsmoothed actual  Base measure
# 2653  2017    County  Average total cost  Unsmoothed actual  Base measure
# 2654  2017    County  Average total cost  Unsmoothed actual  Base measure
#
#                           domain                    condition primary_sex  \
# 0     Primary chronic conditions  Acute myocardial infarction         All
# 1     Primary chronic conditions  Acute myocardial infarction         All
# 2     Primary chronic conditions  Acute myocardial infarction         All
# 3     Primary chronic conditions  Acute myocardial infarction         All
# 4     Primary chronic conditions  Acute myocardial infarction         All
# ...                          ...                          ...         ...
# 2650  Primary chronic conditions  Acute myocardial infarction         All
# 2651  Primary chronic conditions  Acute myocardial infarction         All
# 2652  Primary chronic conditions  Acute myocardial infarction         All
# 2653  Primary chronic conditions  Acute myocardial infarction         All
# 2654  Primary chronic conditions  Acute myocardial infarction         All
#
#      primary_age     primary_dual   fips                county        state  \
# 0            All  Dual & non-dual   1001        Autauga County      ALABAMA
# 1            All  Dual & non-dual   1003        Baldwin County      ALABAMA
# 2            All  Dual & non-dual   1005        Barbour County      ALABAMA
# 3            All  Dual & non-dual   1007           Bibb County      ALABAMA
# 4            All  Dual & non-dual   1009         Blount County      ALABAMA
# ...          ...              ...    ...                   ...          ...
# 2650         All  Dual & non-dual  72061    Guaynabo Municipio  PUERTO RICO
# 2651         All  Dual & non-dual  72097    Mayaguez Municipio  PUERTO RICO
# 2652         All  Dual & non-dual  72113       Ponce Municipio  PUERTO RICO
# 2653         All  Dual & non-dual  72125  San German Municipio  PUERTO RICO
# 2654         All  Dual & non-dual  72127    San Juan Municipio  PUERTO RICO
#
#       urban primary_race primary_denominator  analysis_value
# 0     Urban          All           undefined           40470
# 1     Rural          All           undefined           36615
# 2     Rural          All           undefined           46509
# 3     Urban          All           undefined           42949
# 4     Urban          All           undefined           50067
# ...     ...          ...                 ...             ...
# 2650  Urban          All           undefined           25049
# 2651  Urban          All           undefined           28128
# 2652  Urban          All           undefined           26403
# 2653  Urban          All           undefined           26398
# 2654  Urban          All           undefined           36599
#
# [2655 rows x 17 columns]

# %% [markdown]
# Now examine the last five rows.

# %%
ha_costs_df.tail(5)
# Out:
#       year geography             measure         adjustment      analysis  \
# 2651  2017    County  Average total cost  Unsmoothed actual  Base measure
# 2652  2017    County  Average total cost  Unsmoothed actual  Base measure
# 2653  2017    County  Average total cost  Unsmoothed actual  Base measure
# 2654  2017    County  Average total cost  Unsmoothed actual  Base measure
# 2655  2017    County  Average total cost  Unsmoothed actual  Base measure
#
#                           domain                    condition primary_sex  \
# 2651  Primary chronic conditions  Acute myocardial infarction         All
# 2652  Primary chronic conditions  Acute myocardial infarction         All
# 2653  Primary chronic conditions  Acute myocardial infarction         All
# 2654  Primary chronic conditions  Acute myocardial infarction         All
# 2655  Primary chronic conditions  Acute myocardial infarction         All
#
#      primary_age     primary_dual   fips                   county  \
# 2651         All  Dual & non-dual  72097       Mayaguez Municipio
# 2652         All  Dual & non-dual  72113          Ponce Municipio
# 2653         All  Dual & non-dual  72125     San German Municipio
# 2654         All  Dual & non-dual  72127       San Juan Municipio
# 2655         All  Dual & non-dual  72139  Trujillo Alto Municipio
#
#             state  urban primary_race primary_denominator  analysis_value
# 2651  PUERTO RICO  Urban          All           undefined           28128
# 2652  PUERTO RICO  Urban          All           undefined           26403
# 2653  PUERTO RICO  Urban          All           undefined           26398
# 2654  PUERTO RICO  Urban          All           undefined           36599
# 2655  PUERTO RICO  Urban          All           undefined           26676

# %% [markdown]
# Check the data types of each column by using .info.

# %%
ha_costs_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2656 entries, 0 to 2655
# Data columns (total 17 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   year                 2656 non-null   int64
#  1   geography            2656 non-null   object
#  2   measure              2656 non-null   object
#  3   adjustment           2656 non-null   object
#  4   analysis             2656 non-null   object
#  5   domain               2656 non-null   object
#  6   condition            2656 non-null   object
#  7   primary_sex          2656 non-null   object
#  8   primary_age          2656 non-null   object
#  9   primary_dual         2656 non-null   object
#  10  fips                 2656 non-null   int64
#  11  county               2656 non-null   object
#  12  state                2656 non-null   object
#  13  urban                2656 non-null   object
#  14  primary_race         2656 non-null   object
#  15  primary_denominator  2656 non-null   object
#  16  analysis_value       2656 non-null   int64
# dtypes: int64(3), object(14)
# memory usage: 352.9+ KB

# %% [markdown]
# Keep only the rows where facilities are in TN.

# %%
ha_costs_df_TN = ha_costs_df.loc[ha_costs_df['state'] == 'TENNESSEE']

# %% [markdown]
# Print the dimensions of the resulting dataframe.

# %%
ha_costs_df_TN.shape
# Out:
# (91, 17)

# %% [markdown]
# How many TN counties are represented in the heart attack costs data?

# %%
ha_costs_df_TN['county'].nunique()
# Out:
# 91

# %% [markdown]
# Check to make sure the county names look correct.

# %%
ha_costs_df_TN.county.value_counts()
# Out:
# Tipton County        1
# Overton County       1
# Williamson County    1
# Union County         1
# Knox County          1
#                     ..
# Dyer County          1
# Fentress County      1
# Perry County         1
# Hardin County        1
# Chester County       1
# Name: county, Length: 91, dtype: int64

# %% [markdown]
# How many counties are classified as urban? How many as rural?

# %%
ha_costs_df_TN.urban.value_counts()
# Out:
# Rural    53
# Urban    38
# Name: urban, dtype: int64

# %% [markdown]
# ***
# # Section 2 - Cancer data

# %% [markdown]
# ### Create a DataFrame, cancer_costs_df, from the mmd_cancer_data.csv file.

# %%
cancer_costs_df = pd.read_csv('../data/mmd_cancer_data.csv')

# %% [markdown]
# Look at the head and tail of the DataFrame.

# %%
cancer_costs_df.head(-1)
# Out:
#       year geography             measure         adjustment      analysis  \
# 0     2017    County  Average total cost  Unsmoothed actual  Base measure
# 1     2017    County  Average total cost  Unsmoothed actual  Base measure
# 2     2017    County  Average total cost  Unsmoothed actual  Base measure
# 3     2017    County  Average total cost  Unsmoothed actual  Base measure
# 4     2017    County  Average total cost  Unsmoothed actual  Base measure
# ...    ...       ...                 ...                ...           ...
# 3159  2017    County  Average total cost  Unsmoothed actual  Base measure
# 3160  2017    County  Average total cost  Unsmoothed actual  Base measure
# 3161  2017    County  Average total cost  Unsmoothed actual  Base measure
# 3162  2017    County  Average total cost  Unsmoothed actual  Base measure
# 3163  2017    County  Average total cost  Unsmoothed actual  Base measure
#
#                           domain                                   condition  \
# 0     Primary chronic conditions  Cancer, Colorectal, Breast, Prostate, Lung
# 1     Primary chronic conditions  Cancer, Colorectal, Breast, Prostate, Lung
# 2     Primary chronic conditions  Cancer, Colorectal, Breast, Prostate, Lung
# 3     Primary chronic conditions  Cancer, Colorectal, Breast, Prostate, Lung
# 4     Primary chronic conditions  Cancer, Colorectal, Breast, Prostate, Lung
# ...                          ...                                         ...
# 3159  Primary chronic conditions  Cancer, Colorectal, Breast, Prostate, Lung
# 3160  Primary chronic conditions  Cancer, Colorectal, Breast, Prostate, Lung
# 3161  Primary chronic conditions  Cancer, Colorectal, Breast, Prostate, Lung
# 3162  Primary chronic conditions  Cancer, Colorectal, Breast, Prostate, Lung
# 3163  Primary chronic conditions  Cancer, Colorectal, Breast, Prostate, Lung
#
#      primary_sex primary_age     primary_dual   fips               county  \
# 0            All         All  Dual & non-dual   1001       Autauga County
# 1            All         All  Dual & non-dual   1003       Baldwin County
# 2            All         All  Dual & non-dual   1005       Barbour County
# 3            All         All  Dual & non-dual   1007          Bibb County
# 4            All         All  Dual & non-dual   1009        Blount County
# ...          ...         ...              ...    ...                  ...
# 3159         All         All  Dual & non-dual  72143  Vega Alta Municipio
# 3160         All         All  Dual & non-dual  72145  Vega Baja Municipio
# 3161         All         All  Dual & non-dual  72147    Vieques Municipio
# 3162         All         All  Dual & non-dual  72149   Villalba Municipio
# 3163         All         All  Dual & non-dual  72151    Yabucoa Municipio
#
#             state  urban primary_race primary_denominator  analysis_value
# 0         ALABAMA  Urban          All           undefined           19293
# 1         ALABAMA  Rural          All           undefined           17151
# 2         ALABAMA  Rural          All           undefined           19469
# 3         ALABAMA  Urban          All           undefined           17234
# 4         ALABAMA  Urban          All           undefined           20317
# ...           ...    ...          ...                 ...             ...
# 3159  PUERTO RICO  Urban          All           undefined           12424
# 3160  PUERTO RICO  Urban          All           undefined            7364
# 3161  PUERTO RICO  Rural          All           undefined            9987
# 3162  PUERTO RICO  Urban          All           undefined           24127
# 3163  PUERTO RICO  Urban          All           undefined            8008
#
# [3164 rows x 17 columns]

# %% [markdown]
# Keep only the rows where facilities are in TN.

# %%
cancer_costs_df_TN = cancer_costs_df.loc[cancer_costs_df['state'] == 'TENNESSEE']

# %% [markdown]
# Print the dimensions of the data. How many TN counties are represented in the cancer costs data?

# %%
print(cancer_costs_df_TN.shape)
print('Unique counties =',cancer_costs_df_TN.county.nunique())
# Out:
# (95, 17)
# Unique counties = 95

# %% [markdown]
# You should have found that the datasets have a different number of counties. Bonus: Can you figure out which counties are missing from one of the datasets?

# %%
print('Missing counties in heart attack data =',set(cancer_costs_df_TN.county).difference(set(ha_costs_df_TN.county)))
# Out:
# Missing counties in heart attack data = {'Van Buren County', 'Moore County', 'Pickett County', 'Hancock County'}

# %%
print('Missing counties in cancer data =',set(ha_costs_df_TN.county).difference(set(cancer_costs_df_TN.county)))
# Out:
# Missing counties in cancer data = set()

# %% [markdown]
# ***
# # Section 3 - Income data

# %% [markdown]
# ### Create a DataFrame, income_df, from the irs_county_2016.csv file.

# %%
income_df = pd.read_csv('../data/irs_county_2016.csv')

# %% [markdown]
# Look at the head and the tail.

# %%
income_df.head(-1)
# Out:
#        STATEFIPS STATE  COUNTYFIPS     COUNTYNAME  agi_stub      N1   mars1  \
# 0              1    AL           0        Alabama         1   26450   14680
# 1              1    AL           0        Alabama         2  285760  217880
# 2              1    AL           0        Alabama         3  529780  259680
# 3              1    AL           0        Alabama         4  495750  211100
# 4              1    AL           0        Alabama         5  263130   82330
# ...          ...   ...         ...            ...       ...     ...     ...
# 25530         56    WY          45  Weston County         3     540     320
# 25531         56    WY          45  Weston County         4     610     310
# 25532         56    WY          45  Weston County         5     460     150
# 25533         56    WY          45  Weston County         6     460      90
# 25534         56    WY          45  Weston County         7     460      40
#
#         MARS2   MARS4    PREP  ...  N10300   A10300  N85530  A85530  N85300  \
# 0        9740     680   17780  ...    4300     9256      70      57       0
# 1       25170   39740  143390  ...   70050    40569       0       0       0
# 2       80320  181410  297440  ...  297770   290358       0       0       0
# 3      141800  127420  272030  ...  397940   983800      40      22       0
# 4      137610   35760  154540  ...  252940  1346083      20      27       0
# ...       ...     ...     ...  ...     ...      ...     ...     ...     ...
# 25530     120      90     290  ...     320      330       0       0       0
# 25531     210      70     380  ...     540     1559       0       0       0
# 25532     270      40     300  ...     440     2548       0       0       0
# 25533     330      40     310  ...     450     4072       0       0       0
# 25534     420       0     320  ...     460     7958       0       0       0
#
#        A85300  N11901  A11901  N11902   A11902
# 0           0    2590    3685   11510    35079
# 1           0   22720   11109  237630   263152
# 2           0   41330   40647  474140  1569463
# 3           0   73880  110840  415850  1173195
# 4           0   63240  140446  194790   542205
# ...       ...     ...     ...     ...      ...
# 25530       0      60      66     440     1209
# 25531       0     100     188     490     1377
# 25532       0      90     249     360     1111
# 25533       0     100     333     340     1251
# 25534       0     180     907     260     1045
#
# [25535 rows x 148 columns]

# %% [markdown]
# First verify the unique values for state.

# %%
income_df.STATE.value_counts()
# Out:
# TX    2040
# GA    1280
# VA    1072
# KY     968
# MO     928
# KS     848
# IL     824
# NC     808
# IA     800
# TN     768
# NE     752
# IN     744
# OH     712
# MN     704
# MI     672
# MS     664
# OK     624
# AR     608
# WI     584
# FL     544
# AL     544
# PA     544
# SD     536
# LA     520
# CO     520
# NY     504
# CA     472
# MT     456
# WV     448
# ND     432
# SC     376
# ID     360
# WA     320
# OR     296
# NM     272
# AK     240
# UT     240
# MD     200
# WY     192
# NJ     176
# NV     144
# ME     136
# AZ     128
# MA     120
# VT     120
# NH      88
# CT      72
# RI      48
# HI      40
# DE      32
# DC      16
# Name: STATE, dtype: int64

# %% [markdown]
# Keep only the data that pertains to Tennessee.

# %%
income_df_TN = income_df[income_df.STATE == 'TN']

# %% [markdown]
# Print the shape.

# %%
income_df_TN.shape
# Out:
# (768, 148)

# %% [markdown]
# Keep only the specified columns.

# %%
keep_cols = ['STATE', 'COUNTYNAME', 'agi_stub', 'N1', 'mars1', 'MARS2', 'MARS4', 'N2', 'NUMDEP', 'ELDERLY', 'A00100', 'N02650', 'A02650', 'N02300', 'A02300']
income_df_TN_red = income_df_TN.loc[:,keep_cols]

# %% [markdown]
# Rename those columns.

# %%
income_df_TN_red.columns = ['state', 'county', 'income_bucket', 'return_count', 'single_returns', 'joint_returns', 'head_of_house_returns', 'exemptions', 'dependents', 'elderly', 'agi', 'returns_with_total_inc','total_inc_amt', 'returns_with_unemployment', 'unemployment_comp']

# %%
income_df_TN_red.head(-1)
# Out:
#       state         county  income_bucket  return_count  single_returns  \
# 19752    TN      Tennessee              1         39580           22400
# 19753    TN      Tennessee              2        439770          345410
# 19754    TN      Tennessee              3        717430          398720
# 19755    TN      Tennessee              4        759340          355970
# 19756    TN      Tennessee              5        396810          128390
# ...     ...            ...            ...           ...             ...
# 20514    TN  Wilson County              3         11330            7160
# 20515    TN  Wilson County              4         14400            7130
# 20516    TN  Wilson County              5          9330            2890
# 20517    TN  Wilson County              6          7160            1060
# 20518    TN  Wilson County              7         10350             780
#
#        joint_returns  head_of_house_returns  exemptions  dependents  elderly  \
# 19752          14440                    980       60360        8230    19090
# 19753          39920                  49300      443540      108380    74190
# 19754         115040                 189290     1269420      472350   141070
# 19755         217710                 159890     1486710      512170   154020
# 19756         215890                  42240      881020      268500   106740
# ...              ...                    ...         ...         ...      ...
# 20514           1850                   2040       17420        5260     2650
# 20515           4050                   2610       27040        8660     3140
# 20516           5160                    960       21000        6520     2440
# 20517           5630                    380       18780        6000     1910
# 20518           9260                    240       29640       10040     2600
#
#             agi  returns_with_total_inc  total_inc_amt  \
# 19752  -2747555                   29090       -2710342
# 19753   2366417                  439780        2441687
# 19754  12289681                  717430       12486175
# 19755  27370414                  759340       27694026
# 19756  24350682                  396810       24651803
# ...         ...                     ...            ...
# 20514    194030                   11330         197522
# 20515    526285                   14400         534076
# 20516    577200                    9330         585294
# 20517    621704                    7160         629408
# 20518   1384798                   10350        1404054
#
#        returns_with_unemployment  unemployment_comp
# 19752                         90                348
# 19753                       4830              12132
# 19754                      19660              58771
# 19755                      19120              57012
# 19756                      10630              33894
# ...                          ...                ...
# 20514                        200                673
# 20515                        260                816
# 20516                        160                530
# 20517                        130                485
# 20518                        170                600
#
# [767 rows x 15 columns]
